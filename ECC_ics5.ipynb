# %% [markdown]
# <a href="https://colab.research.google.com/github/GEETA-tech4/DL_CV_Programs/blob/main/ECC_ics5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 2
b = 3
p = 97

base_point = (3, 6)

private_key = 5

public_key_x = (base_point[0] * private_key) % p
public_key_y = (base_point[1] * private_key) % p

print("Private Key :", private_key)

print("Public Key :", (public_key_x, public_key_y))
# Out:
# Private Key : 5
# Public Key : (15, 30)
